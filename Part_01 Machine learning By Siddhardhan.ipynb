# %% [markdown]
# # Module 1: Machine Learning Basics

# %% [markdown]
# 1.1. Artificial Intelligence vs Machine Learning vs Deep Learning
#
# 1.2. Types of Machine Learning: Supervised, Unsupervised & Reinforcement Learning
#
# 1.3. Supervised Learning & its Types
#
# 1.4. Unsupervised Learning & its Types
#
# 1.5. Deep Learning – Basics

# %% [markdown]
# # 1.1. Artificial Intelligence vs Machine Learning vs Deep Learning

# %% [markdown]
# ![AI%20vs%20ML%20vs%20DL%20image.jpg](attachment:AI%20vs%20ML%20vs%20DL%20image.jpg)

# %% [markdown]
# In this Venn Diagram Artificial Intelligence is a broader field and machine learning is subset of Arificial Intelligence
#
# and again deep learning is further subset of machine learning
#
# Machine learning is subset of AI and deep learning is a subset of ML

# %% [markdown]
# # Artificial Intelligence(AI)
#
# Artificial Intelligence is a branch of computer science that is concerned with building  smart and intelligent machines
#
# So,what does Intelligent machines  mean and what does non intelligent machines mean.Lets see below..

# %% [markdown]
# # Non Intelligent Machines
#
# Non Intelligence machines like Bike or watch because these machines can not think, can not make
#
# decisions or do new things they are given a set of work and they just do that work repeatedly
#
# # Intelligent machines
#
# Example of non Intelligent machines are autonomous cars
#
# Consider a test Locker and you can also consider Google assistant which we know encounter it our daily life
#
# So, a tesla car is more Intelligent than Normal Car because it doesn't require any input from the driver and it can drive
#
# the car automatically and Google Assistance is something that you know it uses AI for its function.
#
# The Text Google Assistance in our phone, we dont feel like a computer software we feel like human being.
#
# So these are intelligent  machines beacuse they can think and give you an answer even they do new things and make decisions
#
# of their own which is not impossible in case of non Intelligence machines.
#
# So,Artificial Intelligence is all about making these intelligent machines

# %% [markdown]
# # Machine learning
#
# Machine learning is a technique to implement AI, that can learn from data by themselves without being explicitly
#
# programmed.
#
# So, machine learning is all about the data.
#
# Lets consider a system to detect whether an image is the image of iron man or captain America.
#
# This is the task ,We said for System,So we need to make the system When we take machine learning approach what we will do
#
# is for the machine learning algorithm we will feed numerous images of both iron man and captain america and also we will
#
# tell that algorithm that these images are of iron man and these images are of captain America.
#
# So, Now the Algorithm without  our input it just finds the pattern between the images and when you give a new images it can
#
# predict correctly whether that image of iron man or captain America.
#
# So we give the algorithm a lot of data to learn from .
#
# It is similar to a child seeing something and learning from it .
#
# so we just give it data and we don't need to do anything else.
#
# It can find the pattern and learn from itself this is how we implement AI.

# %% [markdown]
# # Deep learning
#
# Deep learning is again a subfield of machine learning that uses a special type of algorithm called as Artificial neural
#
# network to learn from the data.

# %% [markdown]
# ![DL%20Image.jpg](attachment:DL%20Image.jpg)

# %% [markdown]
# Artificial Neural network are modeled from our human brain.
#
# The neurons present in our human brains ,there are numerous neurons in our brain that are interconnected.
#
# So each neuron process the information and sends the output to another neuron.
#
# This is the same concept used in  case of artificial neural networks.
#
# So they are nothing but  a mathematical model that are connected like the nuerons in our brain
#
# These are the different layes in these artificial neural network
# So, you can see here the first layer is input layer then there are several hidden layers and then there will be outer output lay

# %% [markdown]
# # 1.2. Types of Machine Learning: Supervised, Unsupervised &
#
# # Reinforcement Learning
#
# ![types%20of%20ml.png](attachment:types%20of%20ml.png)

# %% [markdown]
# In supervised learning there is some supervision to the machine learning algorithm by the programmers or by us.
#
# In unsupervised learning there is no supervision for the machine learning and reinforcement learning is completely a
#
# different type and it is not related to each of this supervised and unsupervised learning.

# %% [markdown]
# # Supervised Learning
#
# In supervised Learning, the machine learning algorithm learns from labelled data
#
# So, we already see that you know in machine learning the model learns from the data.
#
# So what is meant by label data set lets say that machine learning model has to see an image and recognize whether the image
#
# represents an apple or mango.
#
# What we will do is we take several images of apples and mangoes and we will tell the machine that these images belongs to
#
# apples and these are the images of mangoes.
#
# Now these apples and mangoes are name it as labels and we feed the label dataset to our machine learning model.
#
# Then our machine learning model or machine learning algorithm tries to find the pattern between these images and onces it
#
# has learned from the data when you give an unknown image it can correctly recognize whether the image represents an apple
#
# or mango.
#
# So this is how supervised learning works and we are telling a supervision in terms of labels.

# %% [markdown]
# # Unsupervised Learning
#
# In Supervised learning ,the machine learning algorithm learns from unlabelled data.
#
# Here we don't tell what that data represents,we won't give any labels .
#
# Lets Consider a example
#
# So we will give several images of apples and mangoes to our machine learning model and we won't tell that these images
#
# belong to apple or these images belong to mango
#
# So we feed all these images without telling what it is to our machine learning model and what it does is. It tries to again
#
# find the pattern and it tries to group all these images and it will group the images into group one and group two
#
# So all the apples will be grouped in one group and all the mangoes will be grouped in another group .
#
# When you give a new image of an apple or a mango it tells you whether it belongs to group one or group two .
#
# This is called as supervised learning because we are not giving any supervision interms of labels

# %% [markdown]
# # Reinforcement Learning
#
# Reinforcement learning is not similar to supervised or unsupervised learning.
#
# It's quite different from both other types
#
# Lets try to understand this in more detail
#
# Reinforcement learning is an area of machine learning concerned with how intelligent agents take actions in an environment
#
# to maximize its rewards
#
# There are four main aspects in reinforcement learning.They are
#
# 1.Environment
#
# 2.Agent
#
# 3.Action
#
# 4.Reward
#
# So, there will be an environment and we need to build an agent that acts in that environment .
#
# So,that agent in that environment tries to take some actions and for that action it agains some rewards.

# %% [markdown]
# For Example
#
# we want to make a computer software or a computer program that can play chess  like a human being
#
# Here our chess board becomes the enviornment and our computer become the agent.
#
# In the environment of chessboard our agent which is the computer tries to take actions.
#
# The actions represents the move the computer takes in the chess and for each step it gets a reward .
#
# So the ultimate reward is winning the chess games and for each step it takes closer to winning it will get a positive
#
# reward.
#
# If it takes a bad step or bad move,so it will get a negative reward.
#
# By this machine tries to learn how to play that game.
#
# Several applications are there for reinforcement learning and all autonomous systems like cars ,Automatic drones are based
#
# on reinforcement learning.
#
# we will try to make an agent that acts in an environment to increase its chance of winning.
#
# ***an "agent" refers to the entity or system that interacts with an environment in order to learn how to perform tasks and maximize certain objectives. The agent's goal is to take actions within the environment to achieve a desired outcome or maximize a cumulative reward over time.
#
# **the "environment" refers to the external system or context in which an agent operates and learns. The environment encompasses everything that the agent interacts with and from which it receives feedback. It provides the context in which the agent takes actions and receives rewards based on its behavior.

# %% [markdown]
# # Types of Supervised Learning
# ![Imageeee.png](attachment:Imageeee.png)

# %% [markdown]
# Classification about predicting a class or discrete value not a continuous value.
#
# It predict classes like Yes or No, Male or Female,True or False etc
#
# Regression Predict Continuous values Like Temparature,Salary etc

# %% [markdown]
# Classification Types
#
# 1.Decision Tree Classification
#
# 2.Random Forest Classification
#
# 3.K-Nearest Neighbour

# %% [markdown]
# Regression Types
#
# 1.Logistic Regression
#
# 2.Ploynomial Regression
#
# 3.Support Vector Recognition

# %% [markdown]
# # Types of Unsupervised Learning

# %% [markdown]
# ![hanu.png](attachment:hanu.png)

# %% [markdown]
# Clustering is an unsupervised task which involves grouping the similar datapoints
#
# Association is an unsupervised task that is used to find important relationship between data points

# %% [markdown]
# Clustering Types
#
# 1.K-means Clustering
#
# 2.Hierarchial Clustering
#
# 3.Principal Component Analysis(PCA)
#
# 4.Apriori
#
# 5.Eclat

# %% [markdown]
# # Deep Learning

# %% [markdown]
# Deep learning is a field of machine learning that uses Artificial Neural Networks to learn from the data
#
# In machine learning we use several data and feed this data to machine learning algorithm to make predictions
#
# But in deep learning we feed specialised algorithm called as Artificial Neural Network
#
# There are three main layers of deep learning
#
# 1.Input layer
#
# 2.Hidden Layer
#
# 3.Output Layer
#
# The main difference between Machine learning and deep learning is we don't need feature extraction manually in deep
#
# learning .But in Machine learning manual feature extraction is Important to predict data.
#
# Applications
#
# Healthcare
#
# Autonomous Cars
#
# Computer vision
#
# Natural Language Processing(NLP)
